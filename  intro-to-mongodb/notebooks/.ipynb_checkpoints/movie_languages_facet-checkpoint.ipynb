# %%
import pymongo
from collections import OrderedDict
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

# Replace XXXX with your connection URI from the Atlas UI
client = MongoClient("mongodb://analytics:analytics-password@mflix-shard-00-00-sed6h.mongodb.net:27017,mflix-shard-00-01-sed6h.mongodb.net:27017,mflix-shard-00-02-sed6h.mongodb.net:27017/test?ssl=true&replicaSet=mflix-shard-0&authSource=admin&retryWrites=true")

pipeline = [
    {
        '$sortByCount': "$language"
    },
    {
        '$facet': {
            'top language combinations': [{'$limit': 100}],
            'unusual combinations shared by': [{
                '$skip': 100
            },
            {
                '$bucketAuto': {
                    'groupBy': "$count",
                    'buckets': 5,
                    'output': {
                        'language combinations': {'$sum': 1}
                    }
                }
            }]
        }
    }
]

clear_output()
pprint.pprint(list(client.mflix.movies_initial.aggregate(pipeline)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/pool.py in _get_socket_no_auth(self)
#     951                     # Can raise ConnectionFailure.
# --> 952                     sock_info = self.sockets.pop()
#     953             except KeyError:
#
# KeyError: 'pop from an empty set'
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/pool.py in connect(self)
#     881         try:
# --> 882             sock = _configured_socket(self.address, self.opts)
#     883         except socket.error as error:
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/pool.py in _configured_socket(address, options)
#     771     """
# --> 772     sock = _create_connection(address, options)
#     773     ssl_context = options.ssl_context
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/pool.py in _create_connection(address, options)
#     755     if err is not None:
# --> 756         raise err
#     757     else:
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/pool.py in _create_connection(address, options)
#     748                 _set_keepalive_times(sock)
# --> 749             sock.connect(sa)
#     750             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# AutoReconnect                             Traceback (most recent call last)
# <ipython-input-1-f9d18736a08e> in <module>()
#      32
#      33 clear_output()
# ---> 34 pprint.pprint(list(client.mflix.movies_initial.aggregate(pipeline)))
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/collection.py in aggregate(self, pipeline, session, **kwargs)
#    2183                                    session=s,
#    2184                                    explicit_session=session is not None,
# -> 2185                                    **kwargs)
#    2186
#    2187     def aggregate_raw_batches(self, pipeline, **kwargs):
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/collection.py in _aggregate(self, pipeline, cursor_class, first_batch_size, session, explicit_session, **kwargs)
#    2053         # If the server does not support the "cursor" option we
#    2054         # ignore useCursor and batchSize.
# -> 2055         with self._socket_for_reads() as (sock_info, slave_ok):
#    2056             dollar_out = pipeline and '$out' in pipeline[-1]
#    2057             if use_cursor:
#
# /usr/local/anaconda/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/mongo_client.py in _socket_for_reads(self, read_preference)
#     981         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
#     982         server = topology.select_server(read_preference)
# --> 983         with self._get_socket(server) as sock_info:
#     984             slave_ok = (single and not sock_info.is_mongos) or (
#     985                 preference != ReadPreference.PRIMARY)
#
# /usr/local/anaconda/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, server)
#     945     def _get_socket(self, server):
#     946         try:
# --> 947             with server.get_socket(self.__all_credentials) as sock_info:
#     948                 yield sock_info
#     949         except NetworkTimeout:
#
# /usr/local/anaconda/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/server.py in get_socket(self, all_credentials, checkout)
#     136     @contextlib.contextmanager
#     137     def get_socket(self, all_credentials, checkout=False):
# --> 138         with self.pool.get_socket(all_credentials, checkout) as sock_info:
#     139             yield sock_info
#     140
#
# /usr/local/anaconda/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/pool.py in get_socket(self, all_credentials, checkout)
#     916         # First get a socket, then attempt authentication. Simplifies
#     917         # semaphore management in the face of network errors during auth.
# --> 918         sock_info = self._get_socket_no_auth()
#     919         try:
#     920             sock_info.check_auth(all_credentials)
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/pool.py in _get_socket_no_auth(self)
#     953             except KeyError:
#     954                 # Can raise ConnectionFailure or CertificateError.
# --> 955                 sock_info = self.connect()
#     956             else:
#     957                 # Can raise ConnectionFailure.
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/pool.py in connect(self)
#     884             if sock is not None:
#     885                 sock.close()
# --> 886             _raise_connection_failure(self.address, error)
#     887
#     888         sock_info = SocketInfo(sock, self, self.address)
#
# /usr/local/anaconda/lib/python3.6/site-packages/pymongo/pool.py in _raise_connection_failure(address, error)
#     271         raise NetworkTimeout(msg)
#     272     else:
# --> 273         raise AutoReconnect(msg)
#     274
#     275
#
# AutoReconnect: mflix-shard-00-00-sed6h.mongodb.net:27017: [Errno 111] Connection refused
